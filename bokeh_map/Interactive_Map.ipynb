# %%
#load external libraries
import numpy as np
import geopandas as gpd
from os.path import join, dirname, abspath
import glob
from bokeh.io import output_notebook, show
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import WMTSTileSource, HoverTool
from bokeh.tile_providers import get_provider, Vendors
from bokeh.models.markers import CircleCross
import pathlib 
import os 

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
path_data = pathlib.Path(r"./data")
path_output = pathlib.Path(r"./output")
if not path_output.exists():
    path_output.mkdir()

# %%
cwd = os.getcwd()

# %%
Loc = os.path.join(cwd,'data/Glacier_locations')
Img = os.path.join(cwd,'data/TWG_images/')

# %%
os.listdir(cwd)
# Out:
# ['data', 'main.py', 'Interactive_Map.ipynb', '.ipynb_checkpoints', 'output']

# %%
sw_data = gpd.read_file(os.path.join(Loc,'Glacier_locations_SW.shp'))
nw_data =  gpd.read_file(os.path.join(Loc,'Glacier_Locations_NW.shp'))
n_data =  gpd.read_file(os.path.join(Loc,'Glacier_locations_N.shp'))
ne_data =  gpd.read_file(os.path.join(Loc,'Glacier_Locations_NE.shp'))
se_data =  gpd.read_file(os.path.join(Loc,'Glacier_Locations_SE.shp'))

# %%
sw_data = sw_data.to_crs({'init':'epsg:3857'})
nw_data = nw_data.to_crs({'init':'epsg:3857'})
n_data = n_data.to_crs({'init':'epsg:3857'})
ne_data = ne_data.to_crs({'init':'epsg:3857'})
se_data = se_data.to_crs({'init':'epsg:3857'})
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
path_sw = glob.glob(os.path.join(Img+'/SW/*.jpg'))
path_nw = glob.glob(os.path.join(Img+'/NW/*.jpg'))
path_n = glob.glob(os.path.join(Img+'/N/*.jpg'))
path_ne = glob.glob(os.path.join(Img+'/NE/*.jpg'))
path_se = glob.glob(os.path.join(Img+'/SE/*.jpg'))

# %%
img_list_sw = []
for i in path_sw:
    img_list_sw.append(abspath(i))
img_list_nw = []
for i in path_nw:
    img_list_nw.append(abspath(i))
img_list_n = []
for i in path_n:
    img_list_n.append(abspath(i))
img_list_ne = []
for i in path_ne:
    img_list_ne.append(abspath(i))
img_list_se = []
for i in path_se:
    img_list_se.append(abspath(i))

# %%
img_list_nw
# Out:
# ['/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0648.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0609.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0637.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN16.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN2.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0661.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0644.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0656.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0572.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0498.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0550.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0452.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0600.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0461.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0655.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0647.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0657.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0503.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0568.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN11_1.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0474.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0651.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0645.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN1_2.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0544.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN7.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN6.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN17.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN8_2.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0490.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN12.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0576.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0486.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN10.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0557.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN15.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN18.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0549.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0529.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN9_1.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0662.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN3.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0542.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0539.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0660.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN4.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0567.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0540_1.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0546.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN8_1.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN1_1.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0659.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0531.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN11_2.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0481.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN13.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0575.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN5.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0540_2.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0518.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0658.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/UN9_2.jpg',
#  '/home/jovyan/bokeh_map/data/TWG_images/NW/GGN0581.jpg']

# %%
sw_data = sw_data.sort_values('Name').reset_index(drop=True)
nw_data = nw_data.sort_values('Name').reset_index(drop=True)
ne_data = ne_data.sort_values('Name').reset_index(drop=True)
se_data = se_data.sort_values('Name').reset_index(drop=True)

# %%
sw_data['x'] = sw_data.geometry.x
sw_data['y'] = sw_data.geometry.y

nw_data['x'] = nw_data.geometry.x
nw_data['y'] = nw_data.geometry.y

n_data['x'] = n_data.geometry.x
n_data['y'] = n_data.geometry.y

ne_data['x'] = ne_data.geometry.x
ne_data['y'] = ne_data.geometry.y

se_data['x'] = se_data.geometry.x
se_data['y'] = se_data.geometry.y

# %%
xList_sw = sw_data.x.values
yList_sw = sw_data.y.values
nameList_sw = sw_data.Name.values

xList_nw = nw_data.x.values
yList_nw = nw_data.y.values
nameList_nw = nw_data.Name.values

xList_n = n_data.x.values
yList_n = n_data.y.values
nameList_n = n_data.Name.values

xList_ne = ne_data.x.values
yList_ne = ne_data.y.values
nameList_ne = ne_data.Name.values

xList_se = se_data.x.values
yList_se = se_data.y.values
nameList_se = se_data.Name.values

# %%
# output_server("Interactive_map")
tile_providers= get_provider('CARTODBPOSITRON')

source_sw = ColumnDataSource(data=dict(
    x=xList_sw,
    y=yList_sw,
    desc = nameList_sw,
    imgs=img_list_sw,
))

source_nw = ColumnDataSource(data=dict(
    x=xList_nw,
    y=yList_nw,
    desc = nameList_nw,
    imgs=img_list_nw,
))

source_n = ColumnDataSource(data=dict(
    x=xList_n,
    y=yList_n,
    desc = nameList_n,
    imgs=img_list_n,
))

source_ne = ColumnDataSource(data=dict(
    x=xList_ne,
    y=yList_ne,
    desc = nameList_ne,
    imgs=img_list_ne,
))

source_se = ColumnDataSource(data=dict(
    x=xList_se,
    y=yList_se,
    desc = nameList_se,
    imgs=img_list_se,
))

TOOLTIPS = """
    <div>
        <div>
            <img
                src="@imgs" height="400" alt="@imgs" width="400"
                style="float: left; margin: 0px 15px 15px 0px;"
                border="2"
            ></img>
        </div>
        <div>
            <span style="font-size: 17px; font-weight: bold;">@desc</span>
            <span style="font-size: 15px; color: #966;">[$index]</span>
        </div>

    </div>
"""
                 
p = figure(x_range=(-2500000, -1000000), y_range=(7500000, 15000000),plot_width=1000, plot_height=700,\
           x_axis_type="mercator", y_axis_type="mercator",tools='pan,box_zoom, reset,\
           wheel_zoom,hover',tooltips= TOOLTIPS)
p.add_tile(tile_providers)

sw = CircleCross(x='x',y='y', size=10, line_color="#355C7D", fill_color=None, line_width=2)
p.add_glyph(source_sw,sw)

nw = CircleCross(x='x',y= 'y', size=10, line_color="#008080", fill_color=None, line_width=2)
p.add_glyph(source_nw,nw)

n= CircleCross(x='x',y='y', size=10, line_color="#F8B195",fill_color=None, line_width=2)
p.add_glyph(source_n, n)

ne = CircleCross(x='x',y='y' ,size=10, line_color="#C06C84", fill_color=None, line_width=2)
p.add_glyph(source_ne, ne)

se = CircleCross(x='x',y='y', size=10, line_color="#F67280",fill_color=None, line_width=2)
p.add_glyph(source_se,se)

show(p)
# Out:
#   <div class="bk-root" id="0a93c84a-1e78-49c9-9de6-e7351c4be96f" data-root-id="4550"></div>
